# %% [markdown]
# ### 获取竞赛数据集
# 首先将竞赛数据集拷贝至您的OBS桶中，将如下代码中"your_obs_path"修改成您的OBS数据存放路径。

# %%
import moxing as mox 
mox.file.copy_parallel('obs://官方路径','obs://your_obs_path')
print('Copy procedure is completed !')
